# %% [markdown]
# ## Get all plugins json
# 1. Open devtools
# 2. Navigate to ChatGPT plugins
# 3. Filter by `https://chat.openai.com/backend-api/aip/p?offset=0`
# 4. Click `p?offset=0...` then click on tab `Preview`
# 5. Copy the value of `items` to `all_plugins.json`

# %%
# DATA FILE

import json
import os
import re
import requests

pypi_path = 'all_plugins.json'

with open(pypi_path, 'r', encoding='utf-8') as f:
    lines = f.readlines()

# Concatenate lines into a single JSON document
json_content = ''.join(lines)

try:
    data = json.loads(json_content)
except json.JSONDecodeError as e:
    print(f"JSONDecodeError: {e}")

# %%
# get the json from blacklist.json
with open('blacklist.json', 'r', encoding='utf-8') as f:
    blacklist = json.load(f)
def aggregate_items(json_object):
    aggregate_list = []
    for key in json_object:
        aggregate_list.extend(json_object[key])
    return aggregate_list
blacklist_list = aggregate_items(blacklist)
blacklist_list
# Out:
# ['Coursera', 'video_insights', 'KAYAK', 'staypia', 'portfoliopilot']

# %%
# ACCEPTED PLUGINS

with open('blacklist.json', 'r', encoding='utf-8') as f:
    blacklist = json.load(f)
def aggregate_items(json_object):
    aggregate_list = []
    for key in json_object:
        aggregate_list.extend(json_object[key])
    return aggregate_list
blacklist_list = aggregate_items(blacklist)

accepted_plugins = []
data = sorted(data, key=lambda k: k['namespace'])
for idx, plugin in enumerate(data):
    if idx % 20 == 0:
        print(f"Checking plugin {idx} out of {len(data)}")
    if plugin and plugin.get("manifest", {}).get("auth", {}).get("type") == "none" and plugin.get("namespace") not in blacklist_list:
        name = plugin.get("namespace")
        # ping the manifest.api.url to see if it is accessible and if so, add it to the plugins.json
        openapi_url = plugin.get("manifest", {}).get("api", {}).get("url")
        if openapi_url:
            try:
                response = requests.get(openapi_url)
                if response.status_code == 200:
                    accepted_plugins.append(plugin)
                else:
                    print(f"Could not access '{name}' with status code {response.status_code}")
            except Exception as e:
                print(f"Could not access '{name}' with error: {e}")
print(f"Accepted plugins {len(accepted_plugins)} out of {len(data)}")
# Out:
# Checking plugin 0 out of 548
# Could not access 'AINewsRoundup' with status code 406
# Could not access 'AusPetrolPrices' with status code 406
# Could not access 'AusSurfReport' with status code 406
# Checking plugin 20 out of 548
# Could not access 'BitcoinSentiment' with status code 406
# Could not access 'CSVExport' with status code 403
# Could not access 'ChatWithGit' with status code 503
# Checking plugin 40 out of 548
# Could not access 'ContentRewriter' with status code 406
# Checking plugin 60 out of 548
# Could not access 'FinTorch_Trading_Assistant' with error: Invalid URL '/openapi.yaml': No scheme supplied. Perhaps you meant https:///openapi.yaml?
# Could not access 'Free_Kiddie_Books' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Could not access 'GeoGuru' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Could not access 'Glowing' with status code 404
# Could not access 'ImageEditor' with error: Invalid URL '/openapi.yaml': No scheme supplied. Perhaps you meant https:///openapi.yaml?
# Checking plugin 80 out of 548
# Could not access 'InterestRates' with status code 406
# Could not access 'Kyujinbox' with status code 404
# Checking plugin 100 out of 548
# Could not access 'NFTNewsRoundup' with status code 406
# Could not access 'NFTs' with status code 406
# Checking plugin 120 out of 548
# Could not access 'PEForNFTs' with status code 406
# Could not access 'PlaylistFollow' with status code 403
# Checking plugin 140 out of 548
# Could not access 'QuakePH' with status code 403
# Could not access 'Rogo' with error: HTTPSConnectionPool(host='plugin.rogodata.com', port=443): Max retries exceeded with url: /plugin/openapi.json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DF4C905A80>, 'Connection to plugin.rogodata.com timed out. (connect timeout=None)'))
# Could not access 'SASpeedCameras' with status code 406
# Could not access 'SEO' with status code 406
# Checking plugin 160 out of 548
# Could not access 'Sentence_Beasts' with status code 403
# Could not access 'Skrive' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Could not access 'Smart_Price_Finder' with status code 403
# Could not access 'SummarizeAnything_pr' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Checking plugin 180 out of 548
# Could not access 'Tabelog' with status code 403
# Checking plugin 200 out of 548
# Could not access 'Web3_User_Activity' with status code 403
# Checking plugin 220 out of 548
# Could not access 'askyourcode' with error: HTTPSConnectionPool(host='plugin.askyourcode.ai', port=443): Max retries exceeded with url: /openapi.yaml (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DF4C904250>, 'Connection to plugin.askyourcode.ai timed out. (connect timeout=None)'))
# Checking plugin 240 out of 548
# Could not access 'bookworm' with status code 403
# Could not access 'california_law_search' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Could not access 'chat_raku_journey' with status code 403
# Checking plugin 260 out of 548
# Could not access 'chatwithwebsite' with status code 503
# Checking plugin 280 out of 548
# Could not access 'copywriter' with status code 406
# Could not access 'crypto_jobs_list' with status code 403
# Could not access 'currencyconverter' with status code 406
# Checking plugin 300 out of 548
# Checking plugin 320 out of 548
# Could not access 'federal_law_search' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Could not access 'filmfindr' with status code 403
# Checking plugin 340 out of 548
# Could not access 'gift_suggester' with status code 502
# Could not access 'godaddy_domains' with status code 403
# Could not access 'hicollectors' with status code 403
# Checking plugin 360 out of 548
# Could not access 'instabase' with status code 404
# Could not access 'kakakucom' with status code 403
# Checking plugin 380 out of 548
# Could not access 'linkReader' with status code 403
# Could not access 'locator' with status code 404
# Could not access 'mbti' with status code 502
# Could not access 'medecinedata' with status code 502
# Checking plugin 400 out of 548
# Checking plugin 420 out of 548
# Could not access 'opentrivia' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Could not access 'penrose_research_analyst' with status code 503
# Checking plugin 440 out of 548
# Could not access 'repo_radar' with error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Could not access 'reviewreader' with status code 403
# Checking plugin 460 out of 548
# Checking plugin 480 out of 548
# Checking plugin 500 out of 548
# Could not access 'vafl' with status code 403
# Checking plugin 520 out of 548
# Could not access 'web_scraper' with error: HTTPSConnectionPool(host='api.gafo.tech', port=443): Max retries exceeded with url: /openapi.yaml (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001DF4C1EF670>: Failed to resolve 'api.gafo.tech' ([Errno 11001] getaddrinfo failed)"))
# Could not access 'wikidocs' with status code 403
# Checking plugin 540 out of 548
# Could not access 'word_counter' with error: Invalid URL '/openapi.json': No scheme supplied. Perhaps you meant https:///openapi.json?
# Accepted plugins 342 out of 548

# %%
# CREATE plugins.json

# for each plugin
all_plugins = {"__testing__": "http://localhost:3333"}
for plugin in accepted_plugins:
    name = plugin.get("namespace")
    all_plugins[name] = "https://" + plugin.get("domain")

# Navigate two directories back from the current working directory
current_dir = os.getcwd()
root_dir = os.path.abspath(os.path.join(current_dir, os.pardir, os.pardir))

pypi_path = os.path.join(root_dir, 'pypi-client', 'openpluginclient', 'plugins.json')
with open(pypi_path, 'w') as f:
    json.dump(all_plugins, f, indent=4, sort_keys=True)
# npm_path = os.path.join(parent_dir, 'npm-client', ..., 'plugins.json')
# with open(npm_path, 'w') as f:
#     json.dump(all_plugins, f, indent=4, sort_keys=True)

print(f"Successfully created plugins.json files with {len(all_plugins)} plugins.")
# Out:
# Successfully created plugins.json files with 341 plugins.

# %%
# CREATE PLUGINS.md

# Create plugins file
current_dir = os.getcwd()
root_dir = os.path.abspath(os.path.join(current_dir, os.pardir, os.pardir))

# Create the file path for plugins.md
pluginsmd_path = os.path.join(root_dir, 'PLUGINS.md')
plugins_md = """
# Plugins
Available plugins for OpenPlugin

| Image | Namespace | Description | Description for model |
| --- | --- | --- | --- |
"""

def escape_special_markdown_chars(text):
    # Characters to escape: \ ` * _ { } [ ] ( ) # + !
    special_chars = r'\\|`|\*|_|{|}|\[|\]|\(|\)|#|\+|!'
    return re.sub(special_chars, lambda match: '\\' + match.group(), text)

def remove_line_breaks(text):
    return text.replace('\n', ' ').replace('\r', '')

for idx, plugin in enumerate(accepted_plugins):
        if idx % 20 == 0:
            print(f"Checking plugin {idx} out of {len(accepted_plugins)}")
        openapi_url = plugin.get("manifest", {}).get("api", {}).get("url")
        if openapi_url:
            try:
                # TODO: this request is repetitive and it could be handled at the ACCEPTED PLUGINS stage
                response = requests.get(openapi_url)
                if response.status_code == 200:
                    image = escape_special_markdown_chars(plugin.get("manifest", {}).get("logo_url"))
                    namespace = escape_special_markdown_chars(plugin.get("namespace"))
                    description = escape_special_markdown_chars(remove_line_breaks(plugin.get("manifest", {}).get("description_for_human")))
                    description_for_model = escape_special_markdown_chars(remove_line_breaks(plugin.get("manifest", {}).get("description_for_model")))
                    plugins_md += f"| ![{namespace} Logo]({image}) | {namespace} | {description} | {description_for_model} |\n"
            except:
                print(f"Error with {plugin.get('namespace')}")

with open(pluginsmd_path, 'w', encoding='utf-8') as f:
    f.write(plugins_md)

print(f"Successfully created PLUGINS.md file with {len(accepted_plugins)} plugins of {len(data)} total plugins.")
# Out:
# Checking plugin 0 out of 342
# Checking plugin 20 out of 342
# Checking plugin 40 out of 342
# Checking plugin 60 out of 342
# Checking plugin 80 out of 342
# Checking plugin 100 out of 342
# Checking plugin 120 out of 342
# Checking plugin 140 out of 342
# Checking plugin 160 out of 342
# Checking plugin 180 out of 342
# Checking plugin 200 out of 342
# Checking plugin 220 out of 342
# Checking plugin 240 out of 342
# Checking plugin 260 out of 342
# Checking plugin 280 out of 342
# Checking plugin 300 out of 342
# Checking plugin 320 out of 342
# Checking plugin 340 out of 342
# Successfully created PLUGINS.md file with 342 plugins of 548 total plugins.
